# %% [markdown]
# ## WEATHER ANALYSIS

# %%
import pandas as pd
import requests as rs
import json
city=["jaipur","bangalore","tirupati","mumbai","chennai","chittoor","nellore","guntur","pune","kolkata"]

temp=[]
cities=[]
weather=[]
k=0
for i in city:
        z=rs.get("http://api.openweathermap.org/data/2.5/weather?q="+i+"&APPID=9c28a85dca23d12779f571c379576d00".format(i))
        dic=json.loads(z.content.decode())
        print(type(z.content.decode()))
        if dic['cod']==200:
            k+1
#             print(k)
#             print('city name:',dic['name'])
#             print('temperature:',dic['main']['temp'])
#             print('wether:',dic['wether'][0]['main'])
            temp.append(dic['main']['temp'])
            cities.append(dic['name'])
            weather.append(dic['weather'][0]['main'])
        else:
            print(i,'spelling is incorrect')

# %%
import pandas as pd
dt=pd.DataFrame({"temperature":temp,"city":city,"wether":weather})
dt
# Out:
#    temperature       city  wether
# 0      315.150     jaipur    Haze
# 1      303.710  bangalore   Clear
# 2      308.150   tirupati  Clouds
# 3      305.650     mumbai  Clouds
# 4      306.150    chennai    Haze
# 5      308.150   chittoor  Clouds
# 6      315.312    nellore  Clouds
# 7      307.150     guntur  Clouds
# 8      308.112       pune   Clear
# 9      308.150    kolkata    Haze

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.plot(temp,city,color='green',linestyle='dashed',linewidth=3,marker='o',markerfacecolor='blue',markersize=10) #line style
plt.xlabel("temperature in kelvin(k)")
plt.ylabel("state capitals of india")
plt.title("temperature variation by state capitals ofdindia")
# Out:
# Text(0.5, 1.0, 'temperature variation by state capitals ofdindia')

# %%
import seaborn as sns    # type of visuvalization
#high-level interface for drawing attractive and informative statistical graphics.

# %%
dt
# Out:
#    temperature       city  wether
# 0      315.150     jaipur    Haze
# 1      303.710  bangalore   Clear
# 2      308.150   tirupati  Clouds
# 3      305.650     mumbai  Clouds
# 4      306.150    chennai    Haze
# 5      308.150   chittoor  Clouds
# 6      315.312    nellore  Clouds
# 7      307.150     guntur  Clouds
# 8      308.112       pune   Clear
# 9      308.150    kolkata    Haze

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.barplot(x=dt.city,y=dt.temperature,hue=dt.wether) #in seaborn dataframe is manditory
plt.legend(loc='upper right') #here we have different options
plt.xlabel("city ")
plt.ylabel("temprature")
# Out:
# Text(0, 0.5, 'temprature')

# %%
#pointplot

plt.figure(figsize=(15,10))
sns.pointplot(x=dt.city,y=dt.temperature,color='lime')
plt.xlabel("cities",fontsize=15,color='red')
plt.ylabel("temp",fontsize=15,color='blue')
plt.title('city vs temp',fontsize=20,color='red')
plt.xticks(rotation=30)
plt.grid() #boxes will come in graph

# %%
x=[1,2,3,4,5]
y=[2,4,5,7,8]
sns.pointplot(x,y,color='red')

# %%
#density --violinplot 
#which area have more density or more points there it will show high density

import seaborn as sns
sns.violinplot(data=dt,inner="box")  #im box place points also can keep
plt.show()  #at 305 to 310 large number of citieims temp is threee
#315 less number of cities data

# %%
import seaborn as sns
x=[100,900,100,110,20,250,100,180,138,134,170,160,180,800,850] #see here  100 range more points ,showing there more density ,in 800 range also some points showing there
#sns.violinplot(data=x,inner="box") 
#sns.violinplot(data=x,inner="quartile") 
sns.violinplot(data=x,inner="sticks",scale="width") 

# still we have many inner types

# %%
#try random num --density plot
import numpy as np
var=np.random.randint(1,100,10)
var
sns.violinplot(data=var,inner="sticks")

# %%
dt
# Out:
#    temperature       city  wether
# 0      315.150     jaipur    Haze
# 1      303.710  bangalore   Clear
# 2      308.150   tirupati  Clouds
# 3      305.650     mumbai  Clouds
# 4      306.150    chennai    Haze
# 5      308.150   chittoor  Clouds
# 6      315.312    nellore  Clouds
# 7      307.150     guntur  Clouds
# 8      308.112       pune   Clear
# 9      308.150    kolkata    Haze

# %%
sns.boxplot(x="wether",y="temperature",data=dt)
plt.show()

# %%
var=np.random.randint(1,1000,10)
var
print(var)
sns.boxplot(data=var) #range 200 to 600 have high density
# Out:
# [128  34 716 267 234 783 165 870 298 308]

# %%
sns.swarmplot(x="wether",y="temperature",data=dt) #it will print in line dots
plt.show()

# %%
sns.heatmap(dt.corr(), annot=True, linewidths=0.5,linecolor="red",fmt='.1f')
plt.show()
